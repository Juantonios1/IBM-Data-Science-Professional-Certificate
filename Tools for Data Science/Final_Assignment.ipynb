# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# Juan Antonio Suwardi
# <br>Data Science

# %% [markdown]
# I am interested in data science because my passion for data science lies on the path to three meaningful outcomes: discovery, insight, and innovation. During my lifetime career as a scientist, I have always used standard methods to analyze data.

# %% [markdown]
# ### I will multiply number

# %%
1 * 2
# Out:
# 2

# %% [markdown]
# * 3 Rules Of Product-Driven Data Science:
#   1. Think backwards
#   2. Build a data pipeline before a model
#   3. Deliver actions over accuracy
# * Keep fighting.
#
# ![XIoPFoOK_400x400.jpg](data:image/jpeg;base64,...)
